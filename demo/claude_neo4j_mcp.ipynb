# %%
import momapy_kb.lpg.session
import momapy_kb.lpg.sbgn.pd
import momapy_kb.lpg.backends.neo4j
from utils import display
import credentials

# %%
backend = momapy_kb.lpg.backends.neo4j.Neo4jBackend(hostname=credentials.HOST_NAME, username=credentials.USER_NAME, password=credentials.PASSWORD)
session = momapy_kb.lpg.session.Session(backend)
session.__enter__()

# %%
query = """
    MATCH (l:Layout)
    RETURN l
"""
results = session.cypher_query_as_layout_elements(query)
for layout_elements in results:
        display(layout_elements)
