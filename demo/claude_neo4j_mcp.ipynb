# %%
import momapy_kb.neo4j.core
import momapy_kb.neo4j.sbgn.pd
from utils import display
import credentials

# %%
momapy_kb.neo4j.core.connect(credentials.HOST_NAME, credentials.USER_NAME, credentials.PASSWORD, notifications_min_severity="off") # connection

# %%
query = """
    MATCH (l:Layout)
    RETURN l
"""
results, _ = momapy_kb.neo4j.core.cypher_query_as_layout_elements(query)
for layout_elements in results:
        display(layout_elements)
